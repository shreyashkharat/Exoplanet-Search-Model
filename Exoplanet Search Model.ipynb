# %% [markdown]
# # Importing Dataset and Data Preprocessing

# %%
import pandas as pd 
data = pd.read_csv(r'F:\Machine Learning and AI\Machine Learning, Deep Learning\Python\Projects\Exoplanet Search Model\archive\cumulative.csv')

# %%
data.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2294 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
# ...

# %% [markdown]
# Removing Name-related variables

# %%
del data['kepoi_name']
del data['kepler_name']
del data['koi_tce_delivname']
del data['koi_tce_plnt_num']

# %% [markdown]
# Deleting empty columns

# %%
del data['koi_teq_err1']
del data['koi_teq_err2']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   koi_disposition    9564 non-null   object
#  3   koi_pdisposition   9564 non-null   object
#  4   koi_score          8054 non-null   float64
#  5   koi_fpflag_nt      9564 non-null   int64
#  6   koi_fpflag_ss      9564 non-null   int64
#  7   koi_fpflag_co      9564 non-null   int64
#  8   koi_fpflag_ec      9564 non-null   int64
#  9   koi_period         9564 non-null   float64
#  10  koi_period_err1    9110 non-null   float64
#  11  koi_period_err2    9110 non-null   float64
#  12  koi_time0bk        9564 non-null   float64
#  13  koi_time0bk_err1   9110 non-null   float64
#  14  koi_time0bk_err2   9110 non-null   float64
#  15  koi_impact         9201 non-null   float64
# ...

# %% [markdown]
# From the above output cell, we note that the following variables need missing value imputation:
# koi_score, koi_period_err1, koi_period_err2, koi_time0bk_err1, koi_time0bk_err2, koi_impact, koi_impact_err1, koi_impact_err2, koi_duration_err1, koi_duration_err2, koi_depth, koi_depth_err1, koi_depth_err2, koi_prad, koi_prad_err1, koi_prad_err2, koi_teq, koi_insol, koi_insol_err1, koi_insol_err2, koi_model_snr, koi_steff, koi_steff_err1, koi_steff_err2, koi_slogg, koi_slogg_err1, koi_slogg_err2, koi_srad, koi_srad_err1, koi_srad_err2, koi_kepmag

# %% [markdown]
# Missing value Imputation

# %%
miss_col = ('koi_score', 'koi_period_err1', 'koi_period_err2', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'koi_kepmag')

# %%
for col in miss_col:
    data[col] = data[col].fillna(data[col].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   koi_disposition    9564 non-null   object
#  3   koi_pdisposition   9564 non-null   object
#  4   koi_score          9564 non-null   float64
#  5   koi_fpflag_nt      9564 non-null   int64
#  6   koi_fpflag_ss      9564 non-null   int64
#  7   koi_fpflag_co      9564 non-null   int64
#  8   koi_fpflag_ec      9564 non-null   int64
#  9   koi_period         9564 non-null   float64
#  10  koi_period_err1    9564 non-null   float64
#  11  koi_period_err2    9564 non-null   float64
#  12  koi_time0bk        9564 non-null   float64
#  13  koi_time0bk_err1   9564 non-null   float64
#  14  koi_time0bk_err2   9564 non-null   float64
#  15  koi_impact         9564 non-null   float64
# ...

# %% [markdown]
# Converting categorical target variables into dummy variables

# %%
data = pd.get_dummies(data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 47 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   rowid                            9564 non-null   int64
#  1   kepid                            9564 non-null   int64
#  2   koi_score                        9564 non-null   float64
#  3   koi_fpflag_nt                    9564 non-null   int64
#  4   koi_fpflag_ss                    9564 non-null   int64
#  5   koi_fpflag_co                    9564 non-null   int64
#  6   koi_fpflag_ec                    9564 non-null   int64
#  7   koi_period                       9564 non-null   float64
#  8   koi_period_err1                  9564 non-null   float64
#  9   koi_period_err2                  9564 non-null   float64
#  10  koi_time0bk                      9564 non-null   float64
#  11  koi_time0bk_err1                 9564 non-null   float64
# ...

# %% [markdown]
# Deleting some dummy variables created to avoid multi-collinearity

# %%
del data['koi_disposition_FALSE POSITIVE']
del data['koi_pdisposition_CANDIDATE']
del data['koi_pdisposition_FALSE POSITIVE']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   rowid                      9564 non-null   int64
#  1   kepid                      9564 non-null   int64
#  2   koi_score                  9564 non-null   float64
#  3   koi_fpflag_nt              9564 non-null   int64
#  4   koi_fpflag_ss              9564 non-null   int64
#  5   koi_fpflag_co              9564 non-null   int64
#  6   koi_fpflag_ec              9564 non-null   int64
#  7   koi_period                 9564 non-null   float64
#  8   koi_period_err1            9564 non-null   float64
#  9   koi_period_err2            9564 non-null   float64
#  10  koi_time0bk                9564 non-null   float64
#  11  koi_time0bk_err1           9564 non-null   float64
#  12  koi_time0bk_err2           9564 non-null   float64
# ...

# %%
corr = data.corr()

# %%
corr
# Out:
#                               rowid     kepid  koi_score  koi_fpflag_nt  \
# rowid                      1.000000  0.021448  -0.427716       0.316824
# kepid                      0.021448  1.000000   0.087421      -0.034676
# koi_score                 -0.427716  0.087421   1.000000      -0.270261
# koi_fpflag_nt              0.316824 -0.034676  -0.270261       1.000000
# koi_fpflag_ss              0.150513 -0.048675  -0.559839      -0.253562
# koi_fpflag_co              0.037656 -0.099944  -0.498053      -0.020810
# koi_fpflag_ec              0.071214 -0.044470  -0.384224       0.027112
# koi_period                 0.003508  0.011511  -0.004200       0.032428
# koi_period_err1            0.185915  0.011336  -0.054121       0.335044
# koi_period_err2           -0.185915 -0.011336   0.054121      -0.335044
# koi_time0bk                0.073668  0.013620  -0.006490       0.250748
# koi_time0bk_err1           0.210091 -0.002170  -0.024897       0.246114
# ...

# %%
del data['rowid']
del data['kepid']

# %%
data.shape
# Out:
# (9564, 42)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   koi_score                  9564 non-null   float64
#  1   koi_fpflag_nt              9564 non-null   int64
#  2   koi_fpflag_ss              9564 non-null   int64
#  3   koi_fpflag_co              9564 non-null   int64
#  4   koi_fpflag_ec              9564 non-null   int64
#  5   koi_period                 9564 non-null   float64
#  6   koi_period_err1            9564 non-null   float64
#  7   koi_period_err2            9564 non-null   float64
#  8   koi_time0bk                9564 non-null   float64
#  9   koi_time0bk_err1           9564 non-null   float64
#  10  koi_time0bk_err2           9564 non-null   float64
#  11  koi_impact                 9564 non-null   float64
#  12  koi_impact_err1            9564 non-null   float64
# ...

# %% [markdown]
# Note that the target variable here has 3 categories, hence can not be represented by a bool.
# We need to make a variable which takes value 0, 1 ,2 as koi_disposition is FALSE POSITIVE, CANDIDATE, CONFIRMED respectively.

# %%
data['koi_disposition'] = [0]*9564

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   koi_score                  9564 non-null   float64
#  1   koi_fpflag_nt              9564 non-null   int64
#  2   koi_fpflag_ss              9564 non-null   int64
#  3   koi_fpflag_co              9564 non-null   int64
#  4   koi_fpflag_ec              9564 non-null   int64
#  5   koi_period                 9564 non-null   float64
#  6   koi_period_err1            9564 non-null   float64
#  7   koi_period_err2            9564 non-null   float64
#  8   koi_time0bk                9564 non-null   float64
#  9   koi_time0bk_err1           9564 non-null   float64
#  10  koi_time0bk_err2           9564 non-null   float64
#  11  koi_impact                 9564 non-null   float64
#  12  koi_impact_err1            9564 non-null   float64
# ...

# %%
for i in range(0, 9564):
    if(data.at[i, 'koi_disposition_CANDIDATE'] == 1):
        data.at[i, 'koi_disposition'] = 1
    elif(data.at[i, 'koi_disposition_CONFIRMED'] == 1):
        data.at[i, 'koi_disposition'] = 2
    elif(data.at[i, 'koi_disposition_CANDIDATE'] == 0 and data.loc[i, 'koi_disposition_CONFIRMED'] == 0):
        data.loc[i, 'koi_disposition'] = 0

# %%
data
# Out:
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0         1.000              0              0              0              0
# 1         0.969              0              0              0              0
# 2         0.000              0              1              0              0
# 3         0.000              0              1              0              0
# 4         1.000              0              0              0              0
# ...         ...            ...            ...            ...            ...
# 9559      0.000              0              0              0              1
# 9560      0.000              0              1              1              0
# 9561      0.497              0              0              0              0
# 9562      0.021              0              0              1              0
# 9563      0.000              0              0              1              1
#
# ...

# %%
del data['koi_disposition_CANDIDATE']
del data['koi_disposition_CONFIRMED']

# %% [markdown]
# ### Train Test split and variable formation

# %%
train_data = data.loc[:6999, :]
test_data = data.loc[7000:, :]

# %%
x_train = train_data.loc[:, train_data.columns != 'koi_disposition']
y_train = train_data['koi_disposition']
x_test = test_data.loc[:, test_data.columns != 'koi_disposition']
y_test = test_data['koi_disposition']

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape, data.shape
# Out:
# ((7000, 40), (7000,), (2564, 40), (2564,), (9564, 41))

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Logistic Model

# %%
from sklearn.linear_model import LogisticRegression
model_log = LogisticRegression(max_iter = 100000)
model_log.fit(x_train, y_train)
# Out:
# C:\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=100000)

# %% [markdown]
# Even after a 100,000 iterations the training of model isn't as the Logistic function here is in 3 dimensions. Anyway let's evaluate it.

# %%
log_train_predict = model_log.predict(x_train)
log_test_predict = model_log.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
con_log_train = confusion_matrix(y_train, log_train_predict)
con_log_test = confusion_matrix(y_test, log_test_predict)

# %%
con_log_train
# Out:
# array([[2559,  224,  311],
#        [ 575,  212,  876],
#        [ 285,   65, 1893]], dtype=int64)

# %%
con_log_test
# Out:
# array([[1717,   88,  124],
#        [ 295,   52,  238],
#        [  21,    2,   27]], dtype=int64)

# %%
log_train_acc = accuracy_score(y_train, log_train_predict)
log_test_acc = accuracy_score(y_test, log_test_predict)
log_train_acc, log_test_acc
# Out:
# (0.6662857142857143, 0.7004680187207488)

# %% [markdown]
# The accuracy of Logistic Model is fine, better performance can be given by other models.

# %% [markdown]
# ## Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as lda
model_lda = lda()
model_lda.fit(x_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
lda_train_predict = model_lda.predict(x_train)
lda_test_predict = model_lda.predict(x_test)

# %%
con_lda_train = confusion_matrix(y_train, lda_train_predict)
con_lda_test = confusion_matrix(y_test, lda_test_predict)

# %%
con_lda_train
# Out:
# array([[2980,  113,    1],
#        [  21,  730,  912],
#        [  46,  173, 2024]], dtype=int64)

# %%
con_lda_test
# Out:
# array([[1915,   14,    0],
#        [  29,  377,  179],
#        [   3,   12,   35]], dtype=int64)

# %%
lda_train_acc = accuracy_score(y_train, lda_train_predict)
lda_test_acc = accuracy_score(y_test, lda_test_predict)
lda_train_acc, lda_test_acc
# Out:
# (0.8191428571428572, 0.9075663026521061)

# %% [markdown]
# The Linear Discriminant Analysis has a good performance, but it's not state-of-the-art.

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
k_hyper = {'n_neighbors': range(1, 101)}

# %%
grid_search = GridSearchCV(KNeighborsClassifier(), k_hyper)

# %%
from sklearn import preprocessing
scaler_train = preprocessing.StandardScaler().fit(x_train)
x_train_scaled = scaler_train.transform(x_train)
scaler_test = preprocessing.StandardScaler().fit(x_test)
x_test_scaled = scaler_test.transform(x_test)

# %%
grid_search.fit(x_train_scaled, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 101)})

# %%
grid_search.best_params_
# Out:
# {'n_neighbors': 24}

# %%
model_knn = grid_search.best_estimator_

# %%
knn_train_predict = model_knn.predict(x_train_scaled)
knn_test_predict = model_knn.predict(x_test_scaled)

# %%
con_knn_train = confusion_matrix(y_train, knn_train_predict)
con_knn_test = confusion_matrix(y_test, knn_test_predict)

# %%
con_knn_train
# Out:
# array([[3032,   54,    8],
#        [  94,  810,  759],
#        [  50,  181, 2012]], dtype=int64)

# %%
con_knn_test
# Out:
# array([[1779,   74,   76],
#        [  24,  240,  321],
#        [   1,    8,   41]], dtype=int64)

# %%
knn_train_acc = accuracy_score(y_train, knn_train_predict)
knn_test_acc = accuracy_score(y_test, knn_test_predict)
knn_train_acc, knn_test_acc
# Out:
# (0.8362857142857143, 0.8034321372854915)

# %% [markdown]
# This model behaves well, the previous model has test set accuracy greater than train set accuracy, the main reason for this is irregular distribution of data, as these is astronomical data recorded we highly accurate instruments. Some observations might seem as outliers but there's a high probability that the observation is not a outlier but a genuine observation. Due to this the data might have a irregular distribution. The distribution doesn't affect K-Nearest Model as this model doesn't use any function but uses geometric arguements to estimate the target variable.

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree1 = DecisionTreeClassifier(min_samples_split = 25)

# %%
tree1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=25)

# %%
tree1_train_predict = tree1.predict(x_train)
tree1_test_predict = tree1.predict(x_test)

# %%
con_tree1_train = confusion_matrix(y_train, tree1_train_predict)
con_tree1_test = confusion_matrix(y_test, tree1_test_predict)

# %%
con_tree1_train
# Out:
# array([[3068,   21,    5],
#        [  23, 1440,  200],
#        [  28,  199, 2016]], dtype=int64)

# %%
con_tree1_test
# Out:
# array([[1899,   12,   18],
#        [  61,  452,   72],
#        [   4,   18,   28]], dtype=int64)

# %%
tree1_train_acc = accuracy_score(y_train, tree1_train_predict)
tree1_test_acc = accuracy_score(y_test, tree1_test_predict)
tree1_train_acc, tree1_test_acc
# Out:
# (0.932, 0.9278471138845554)

# %%
tree2 = DecisionTreeClassifier(min_samples_leaf = 5)

# %%
tree2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=5)

# %%
tree2_train_predict = tree2.predict(x_train)
tree2_test_predict = tree2.predict(x_test)

# %%
con_tree2_train = confusion_matrix(y_train, tree2_train_predict)
con_tree2_test = confusion_matrix(y_test, tree2_test_predict)

# %%
con_tree2_train
# Out:
# array([[3070,   17,    7],
#        [  31, 1483,  149],
#        [  20,  148, 2075]], dtype=int64)

# %%
con_tree2_test
# Out:
# array([[1907,    8,   14],
#        [  62,  460,   63],
#        [   3,   21,   26]], dtype=int64)

# %%
tree2_train_acc = accuracy_score(y_train, tree2_train_predict)
tree2_test_acc = accuracy_score(y_test, tree2_test_predict)
tree2_train_acc, tree2_test_acc
# Out:
# (0.9468571428571428, 0.9333073322932918)

# %% [markdown]
# The trees have given a good accuracy.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ran_for = RandomForestClassifier(n_estimators = 10000, n_jobs = -1, random_state = 0)

# %%
ran_for.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10000, n_jobs=-1, random_state=0)

# %%
ran_train_predict = ran_for.predict(x_train)
ran_test_predict = ran_for.predict(x_test)

# %%
con_ran_train = confusion_matrix(y_train, ran_train_predict)
con_ran_test = confusion_matrix(y_test, ran_test_predict)

# %%
con_ran_train
# Out:
# array([[3094,    0,    0],
#        [   0, 1663,    0],
#        [   0,    0, 2243]], dtype=int64)

# %%
con_ran_test
# Out:
# array([[1929,    0,    0],
#        [  53,  516,   16],
#        [   2,   25,   23]], dtype=int64)

# %%
ran_train_acc = accuracy_score(y_train, ran_train_predict)
ran_test_acc = accuracy_score(y_test, ran_test_predict)
ran_train_acc, ran_test_acc
# Out:
# (1.0, 0.9625585023400937)
